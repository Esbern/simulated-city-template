# %% [markdown]
# # Simulated City Basics
#
# This notebook introduces the minimal agent-based simulation in `simulated_city`.
#
# - Create a city
# - Populate agents + places
# - Step the simulation
# - Visualize a simple grid snapshot

# %%
from simulated_city.sim import CitySim
from simulated_city.viz import grid_to_ascii

# %%
sim = CitySim(width=30, height=15, seed=42)
sim.populate_random(n_agents=60, n_places=10)
sim.metrics()

# %%
for _ in range(10):
    sim.step()

sim.metrics()

# %%
grid = sim.snapshot_grid()
print(grid_to_ascii(grid))

# %% [markdown]
# ## Optional: quick heatmap
#
# This uses `matplotlib` (installed via the `notebooks` extra).

# %%
import matplotlib.pyplot as plt

plt.imshow(grid, cmap="viridis")
plt.colorbar(label="agents per cell")
plt.title(f"Agent density at step {sim.step_index}")
plt.show()
